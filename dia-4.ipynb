# %% [markdown]
# Challenge 1 🤺
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %%
datos_del_personal= {
    'Nombre': 'Rocio Anhia', 
    'Apellido': 'velazquez',
    'Domicilio': 'Brasilia 2.863',
    'Edad': '28', 
    'Sexo': 'Femenino', 
    'Telefono': '0992759640', 
    'Corre Electronico Personal':'anahi.velazquezgmail.com'} 
    
   
print (datos_del_personal)
print (datos_del_personal) ['Correo Electronico Laboral':'anahivelazquez@mercado.com']
# Out:
#   Cell In[4], line 12
#     print (datos_del_personal)=['Correo Electronico Laboral':'anahivelazquez@mercado.com']
#     ^
# SyntaxError: cannot assign to function call

# %% [markdown]
# Challenge 2 🤺
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# 1. Crear datos nuevos
# 2. Modificar datos
# 3. Eliminar datos

# %%
tarjeta_personal= {}
opcion_usuario = input ('ingrese opcion')

if opcion_usuario == '1':
    clave_usuario = input('ingrese la clave')
    valor_usuario = input('ingrese el valor')
    tarjeta_personal[clave_usuario]= valor_usuario
    print(tarjeta_personal)

elif opcion_usuario == '2':
    print(tarjeta_personal)
    clave_usuario=input('ingrese la clave')
    valor_usuario=input('ingrese el valor')
    tarjeta_personal=[clave_usuario]=valor_usuario
    print(tarjeta_personal)
# Out:
# {'Nombre': 'Rocio Anhia', 'Apellido': 'velazquez', 'Anahi': ''}

# %% [markdown]
# Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# 1. Mostrar los contactos
# 2. Crear contacto
# 3. Modificar datos del contacto

# %%
clave='Anahi Lopez'
valor= {'Telefono': '0982547720', 'Mail': 'anahilopez@next.com'}

agenda=[clave]=valor

print(agenda)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 clave='Anahi Lopez'
#       2 valor= {'Telefono': '0982547720', 'Mail': 'anahilopez@next.com'}
# ----> 4 agenda=[clave]=valor
#       6 print(agenda)
#
# ValueError: too many values to unpack (expected 1)
