# %% [markdown]
# Challenge 🤺15 min
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# °Atributos de clase: especie.
# °Atributos de instancia: nombre & color.
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %%
class Mamifero :
    especie='conejo'
    ojos= 2
    orejas= 2
    patas= 4
    cola= 1

    def _init_(self, nombre, color):
        self.nombre= nombre
        self.color= color

conejo1= Mamifero ('Raul','blanco')

print(f'Me llamo{conejo1.nombre}soy un conejo de color {conejo1.color}')

conejo2= Mamifero ('Sami','gris')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 12
#       9         self.nombre=nombre
#      10         self.color=color
# ---> 12 conejo1= Mamifero ('Raul', 'blanco')
#      14 print(f'Me llamo{conejo1.nombre}soy un conejo de color{conejo1.color}')
#      16 conejo2= Mamifero ('Sami', 'gris')
#
# TypeError: Mamifero() takes no arguments

# %% [markdown]
# Challenge 🤺
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
class :

# %%
class Animales():
    especie = 'Ave'
    def _init_(self,color,nombre):
        self.color = color
        self.nombre = nombre

    def hablar (self,animal):
        print(f'El/la {animal} esta hablando')

    def mover (self,animal):
        print(f'El/la {animal} se esta moviendo')

pajaro = Animales('azul','alan')
print(f'Me llamo {pajaro.nombre} y soy una {pajaro.especie} de color {pajaro.color}')
pajaro.hablar(pajaro.especie)
pajaro.mover(pajaro.especie)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10     def mover (self,animal):
#      11         print(f'El/la {animal} se esta moviendo')
# ---> 13 pajaro = Animales('azul','alan')
#      14 print(f'Me llamo {pajaro.nombre} y soy una {pajaro.especie} de color {pajaro.color}')
#      15 pajaro.hablar(pajaro.especie)
#
# TypeError: Animales() takes no arguments

# %%
class Animales:
    especie = 'vacas'

    def __init__(self, nombre, posicion=0):
        self.nombre = nombre
        self.posicion = posicion

    def correr(self, metros):
        self.metros = metros
        self.posicion = self.posicion + self.metros
        print(f'la vaca {self.nombre} corrio {self.metros}')

    def escapa(self):
        if self.posicion > 50:
            print(f'la vaca {self.nombre} logro escapar')
        else:
            print(f'la vaca {self.nombre} no pudo escapar :c')

vaca1 = Animales('lola')
print(vaca1.nombre)

vaca1.correr(40)
vaca1.escapa()
vaca1.correr(20)
vaca1.escapa()
# Out:
# lola
# la vaca lola corrio 40
# la vaca lola no pudo escapar :c
# la vaca lola corrio 20
# la vaca lola logro escapar

# %% [markdown]
# Challenge 🤺15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Motociclo:
    cilindrada= 225
    def __init__(self,marca, color):
        self.marca=marca
        self.color=color 

    def honda (self,):
        print('electrico')

         (self)
        print('silencioso')

class

# %% [markdown]
# Challenge 🤺 15
#
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
class Heroe:
     nombre = Rosch
     fueza = Fuego
     def __init__(self, nombre,fuerza ):
          self.nombre=nombre
          self.fueza=fuerza
          print()
