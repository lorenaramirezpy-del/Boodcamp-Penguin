# %% [markdown]
# Challenge 1 🤺 - 15m
# Crear una función que imprima la variable palabra.

# %%
def imprimir():
    palabra = ('Hola gente!')
    print(palabra)
imprimir()
# Out:
# Hola gente!

# %% [markdown]
# Challenge 2 🤺 - 15 min
# Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:
#
# 1.Si son iguales, imprimir "Las letras son iguales".
#
# 2.De lo contrario, imprimir "Las letras son diferentes".

# %%
def verificar(letra1 , letra2):
    if letra1 == letra2 : 
        print ('Las letras son iguales') 
    else:
        print ('Las letras son diferentes')

verificar('l' , 'f')
# Out:
# Las letras son diferentes

# %% [markdown]
# Challenge 3 🤺 - 20m
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# imprimir resultado de la funcion.
#
# Pista: cantidad de letras de una palabra en python

# %%
def verificar_funcion(palabra, numero):
    return len(palabra) == numero

print(verificar_funcion("hola", 4))    #--->> true
print(verificar_funcion("python", 6))  #--->> true
print(verificar_funcion("sol", 5))     #--->>false

input('ingrese resultado de la funcion: ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 print(verificar_funcion("python", 6))  #--->> true
#       6 print(verificar_funcion("sol", 5))     #--->>false
# ----> 8 input('ingrese resultado de la funcion: ')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# Challenge 5 🤺 - 25m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra

# %%
palabra_ingresada=[]
usurioa = input ('ingrese la palabra')
palabra_ingresada1 = list (usuario)
lista_palabras.appen (palabra_ingresada1)

print (lista_palabras) 

palabra_ingresada2 = list (usuario)
lista_palabras.appen (palabra_ingresada2)

print (lista_palabras) 

palabra_ingresada3 = list (usuario)
lista_palabras.appen (palabra_ingresada3)

print (lista_palabras)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 palabra_ingresada=[]
#       2 usurioa = input ('ingrese la palabra')
# ----> 3 palabra_ingresada1 = list (usuario)
#       4 lista_palabras.appen (palabra_ingresada1)
#       6 print (lista_palabras)
#
# NameError: name 'usuario' is not defined

# %%
def obtener_fela_verifi ada (papalabra _a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5
#creamos una lista vacia para almacenar el resultado
letras_verificadas = []
for posicion in range (cantidad_letras_de_palabra_a_encontrar): #5
    # es igual en indice 0 de palabrs_a_encontrar a indice 0 de palabra_ingresada
    cantidad_letras_de_palabra_a_encontrar[posicion] == palabra_ingresada[posicion]
    la_palabra_existe_en_la_palabra = palabra_ingresada [posicion] in cantidad_letras_de_palabra_a_encontrar
    if las_letras_son_iguales:
        # si se cumple guardamos en la lista de letras verificadas 
        letras_verificadas.append ('[+ palabra_ingresada[posicion]+]')

    elif la_palabra_existe_en_la_palabra:
        letras_verificadas.append('(' +palabra_ingresada[posicion]+')')
        
    else:
        letras_verificadas.append(palabra_ingresada[posicion])

  return letras_verificadas

resultado = obtener_fila_verificada ('perro', 'juego')     
print(resultado)

# %% [markdown]
# Challenge 6 🤺 - 25m
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def desglozar_lista(lista):
    for i in range (len(lista)):
        print(lista[i])

desglozar_lista (lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
